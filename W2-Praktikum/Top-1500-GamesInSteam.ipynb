# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %matplotlib inline

# %% [markdown]
# # Tentang Dataset
# https://www.kaggle.com/datasets/alicemtopcu/top-1500-games-on-steam-by-revenue-09-09-2024

# %% [markdown]
# ## 1. Preparing Data

# %%
df = pd.read_csv('Steam_2024_bestRevenue_1500.csv')
df.head()
# Out:
#                               name releaseDate  copiesSold  price    revenue  \
# 0                         WWE 2K24  07-03-2024      165301  99.99  8055097.0
# 1            EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2        Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3                 Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 4  Shin Megami Tensei V: Vengeance  13-06-2024      141306  59.99  7629252.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 0    42.365140           71            AAA                           2K
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 4    34.258496           96             AA                         SEGA
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940
# 3                                    Obb Studio Inc.  1859910
# 4                                              ATLUS  1875830

# %% [markdown]
# ## 2. Clearing Data

# %%
df.head()
# Out:
#                               name releaseDate  copiesSold  price    revenue  \
# 0                         WWE 2K24  07-03-2024      165301  99.99  8055097.0
# 1            EARTH DEFENSE FORCE 6  25-07-2024      159806  59.99  7882151.0
# 2        Sins of a Solar Empire II  15-08-2024      214192  49.99  7815247.0
# 3                 Legend of Mortal  14-06-2024      440998  19.99  7756399.0
# 4  Shin Megami Tensei V: Vengeance  13-06-2024      141306  59.99  7629252.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 0    42.365140           71            AAA                           2K
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 4    34.258496           96             AA                         SEGA
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940
# 3                                    Obb Studio Inc.  1859910
# 4                                              ATLUS  1875830

# %%
df.isna().sum()
# Out:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        1
# developers        2
# steamId           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        0
# developers        0
# steamId           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 1497

# %%
df.nunique()
# Out:
# name              1497
# releaseDate        235
# copiesSold        1457
# price               58
# revenue           1494
# avgPlaytime       1497
# reviewScore         72
# publisherClass       3
# publishers        1131
# developers        1405
# steamId           1497
# dtype: int64

# %% [markdown]
# ## 3. Feature Engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1497 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1497 non-null   object
#  1   releaseDate     1497 non-null   object
#  2   copiesSold      1497 non-null   int64
#  3   price           1497 non-null   float64
#  4   revenue         1497 non-null   float64
#  5   avgPlaytime     1497 non-null   float64
#  6   reviewScore     1497 non-null   int64
#  7   publisherClass  1497 non-null   object
#  8   publishers      1497 non-null   object
#  9   developers      1497 non-null   object
#  10  steamId         1497 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 140.3+ KB

# %% [markdown]
# #### Buat salinan data

# %%
df_tmp = df.copy()

# %%
df_tmp['releaseDate'] = pd.to_datetime(df_tmp['releaseDate'],format='%d-%m-%Y')
df_tmp.head()
# Out:
#                               name releaseDate  copiesSold  price    revenue  \
# 0                         WWE 2K24  2024-03-07      165301  99.99  8055097.0
# 1            EARTH DEFENSE FORCE 6  2024-07-25      159806  59.99  7882151.0
# 2        Sins of a Solar Empire II  2024-08-15      214192  49.99  7815247.0
# 3                 Legend of Mortal  2024-06-14      440998  19.99  7756399.0
# 4  Shin Megami Tensei V: Vengeance  2024-06-13      141306  59.99  7629252.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 0    42.365140           71            AAA                           2K
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 4    34.258496           96             AA                         SEGA
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940
# 3                                    Obb Studio Inc.  1859910
# 4                                              ATLUS  1875830

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1497 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1497 non-null   object
#  1   releaseDate     1497 non-null   datetime64[ns]
#  2   copiesSold      1497 non-null   int64
#  3   price           1497 non-null   float64
#  4   revenue         1497 non-null   float64
#  5   avgPlaytime     1497 non-null   float64
#  6   reviewScore     1497 non-null   int64
#  7   publisherClass  1497 non-null   object
#  8   publishers      1497 non-null   object
#  9   developers      1497 non-null   object
#  10  steamId         1497 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(4)
# memory usage: 140.3+ KB

# %%
df_tmp = df_tmp.sort_values('releaseDate', ascending=True).reset_index()
df_tmp.head()
# Out:
#    index                   name releaseDate  copiesSold  price   revenue  \
# 0    119         Shipwrecked 64  2024-01-01       26225   7.99  202048.0
# 1    503  Mothers and Daughters  2024-01-02        7578   9.99   64494.0
# 2   1399   Alex Jones: NWO Wars  2024-01-03       20806  17.76  323316.0
# 3    940              Akai Onna  2024-01-04       12475   2.99   28485.0
# 4    996      TRAMCITY HAKODATE  2024-01-04        1888  14.99   25471.0
#
#    avgPlaytime  reviewScore publisherClass     publishers  \
# 0     7.407743           96          Indie  Cogware Games
# 1     4.364727           67          Indie        Spin256
# 2     1.366906           94          Indie  NWO Wars Team
# 3     0.692439           89          Indie         Yamoto
# 4     2.946588          100          Indie      TRAMWORKS
#
#                        developers  steamId
# 0  Squeaks D'Corgeh,Cogware Games  2160220
# 1                         Spin256  2508400
# 2                   NWO Wars Team  2487350
# 3                          Yamoto  2674190
# 4                       TRAMWORKS  2614000

# %%
# Temukan tanggal maksimum di kolom release_date
max_date = df_tmp['releaseDate'].max()

# Hitung selisih hari antara max_date dan release_date
df_tmp['days_since_max_release'] = (max_date - df_tmp['releaseDate']).dt.days

# %%
df_tmp.head()
# Out:
#    index                   name releaseDate  copiesSold  price   revenue  \
# 0    119         Shipwrecked 64  2024-01-01       26225   7.99  202048.0
# 1    503  Mothers and Daughters  2024-01-02        7578   9.99   64494.0
# 2   1399   Alex Jones: NWO Wars  2024-01-03       20806  17.76  323316.0
# 3    940              Akai Onna  2024-01-04       12475   2.99   28485.0
# 4    996      TRAMCITY HAKODATE  2024-01-04        1888  14.99   25471.0
#
#    avgPlaytime  reviewScore publisherClass     publishers  \
# 0     7.407743           96          Indie  Cogware Games
# 1     4.364727           67          Indie        Spin256
# 2     1.366906           94          Indie  NWO Wars Team
# 3     0.692439           89          Indie         Yamoto
# 4     2.946588          100          Indie      TRAMWORKS
#
#                        developers  steamId  days_since_max_release
# 0  Squeaks D'Corgeh,Cogware Games  2160220                     249
# 1                         Spin256  2508400                     248
# 2                   NWO Wars Team  2487350                     247
# 3                          Yamoto  2674190                     246
# 4                       TRAMWORKS  2614000                     246

# %%
max_date
# Out:
# Timestamp('2024-09-06 00:00:00')

# %%
df_tmp.describe()
# Out:
#              index                    releaseDate    copiesSold        price  \
# count  1497.000000                           1497  1.497000e+03  1497.000000
# mean    749.587174  2024-05-05 02:19:28.737474560  1.417444e+05    17.531263
# min       0.000000            2024-01-01 00:00:00  5.930000e+02     0.000000
# 25%     374.000000            2024-03-07 00:00:00  4.922000e+03     9.990000
# 50%     750.000000            2024-05-02 00:00:00  1.197200e+04    14.990000
# 75%    1125.000000            2024-06-27 00:00:00  3.831300e+04    19.990000
# max    1499.000000            2024-09-06 00:00:00  3.073915e+07    99.990000
# std     433.580973                            NaN  1.133877e+06    12.649514
#
#             revenue  avgPlaytime  reviewScore       steamId  \
# count  1.497000e+03  1497.000000  1497.000000  1.497000e+03
# mean   2.637561e+06    12.580062    76.205745  2.184222e+06
# min    2.067400e+04     0.000000     0.000000  2.488000e+04
# 25%    4.551800e+04     3.571454    72.000000  1.793090e+06
# 50%    1.099730e+05     6.763299    83.000000  2.321880e+06
# 75%    4.571630e+05    13.108251    92.000000  2.693730e+06
# max    8.377934e+08   296.332852   100.000000  3.107330e+06
# std    2.783787e+07    21.559777    24.342595  6.060862e+05
#
#        days_since_max_release
# count              1497.00000
# mean                123.90314
# min                   0.00000
# 25%                  71.00000
# 50%                 127.00000
# 75%                 183.00000
# max                 249.00000
# std                  68.07320

# %%
# Tentukan apakah game tersebut baru atau tidak
df_tmp['is_new'] = df_tmp['days_since_max_release'].apply(lambda x: 'New' if x <= 30 else 'Old')

# %%
df_tmp.head()
# Out:
#    index                   name releaseDate  copiesSold  price   revenue  \
# 0    119         Shipwrecked 64  2024-01-01       26225   7.99  202048.0
# 1    503  Mothers and Daughters  2024-01-02        7578   9.99   64494.0
# 2   1399   Alex Jones: NWO Wars  2024-01-03       20806  17.76  323316.0
# 3    940              Akai Onna  2024-01-04       12475   2.99   28485.0
# 4    996      TRAMCITY HAKODATE  2024-01-04        1888  14.99   25471.0
#
#    avgPlaytime  reviewScore publisherClass     publishers  \
# 0     7.407743           96          Indie  Cogware Games
# 1     4.364727           67          Indie        Spin256
# 2     1.366906           94          Indie  NWO Wars Team
# 3     0.692439           89          Indie         Yamoto
# 4     2.946588          100          Indie      TRAMWORKS
#
#                        developers  steamId  days_since_max_release is_new
# 0  Squeaks D'Corgeh,Cogware Games  2160220                     249    Old
# 1                         Spin256  2508400                     248    Old
# 2                   NWO Wars Team  2487350                     247    Old
# 3                          Yamoto  2674190                     246    Old
# 4                       TRAMWORKS  2614000                     246    Old

# %% [markdown]
# #### Kita bisa hapus colom `releaseDate` karena data sudah tidak dipakai lagi

# %%
df_tmp.drop('steamId', axis=1, inplace=True)

# %%
df_tmp.drop('index', axis=1, inplace=True)

# %%
df_tmp.drop('releaseDate', axis=1, inplace=True)
df_tmp.head()
# Out:
#                     name  copiesSold  price   revenue  avgPlaytime  \
# 0         Shipwrecked 64       26225   7.99  202048.0     7.407743
# 1  Mothers and Daughters        7578   9.99   64494.0     4.364727
# 2   Alex Jones: NWO Wars       20806  17.76  323316.0     1.366906
# 3              Akai Onna       12475   2.99   28485.0     0.692439
# 4      TRAMCITY HAKODATE        1888  14.99   25471.0     2.946588
#
#    reviewScore publisherClass     publishers                      developers  \
# 0           96          Indie  Cogware Games  Squeaks D'Corgeh,Cogware Games
# 1           67          Indie        Spin256                         Spin256
# 2           94          Indie  NWO Wars Team                   NWO Wars Team
# 3           89          Indie         Yamoto                          Yamoto
# 4          100          Indie      TRAMWORKS                       TRAMWORKS
#
#    days_since_max_release is_new
# 0                     249    Old
# 1                     248    Old
# 2                     247    Old
# 3                     246    Old
# 4                     246    Old

# %% [markdown]
# ## 4. EDA

# %%
df_tmp.nunique()
# Out:
# name                      1497
# copiesSold                1457
# price                       58
# revenue                   1494
# avgPlaytime               1497
# reviewScore                 72
# publisherClass               3
# publishers                1131
# developers                1405
# days_since_max_release     235
# is_new                       2
# dtype: int64

# %%
play_time_rates = pd.DataFrame(df_tmp.groupby("is_new")["price"].mean().reset_index())
play_time_rates
# Out:
#   is_new      price
# 0    New  19.724695
# 1    Old  17.261403

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='is_new', y='price', data=play_time_rates, hue='is_new', palette='crest')
plt.title('Rata-Rata Harga Berdasarkan Versi Game')
plt.xlabel('Versi Game')
plt.ylabel('Avg Price')
plt.show()

# %%
top_publisher = pd.DataFrame(df.publisherClass.value_counts().reset_index())
top_publisher
# Out:
#   publisherClass  count
# 0          Indie   1299
# 1             AA    146
# 2            AAA     52

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='publisherClass', y='count', data=top_publisher, hue='publisherClass', palette='crest')
plt.title('Top Publisher Class')
plt.xlabel('Publisher Class')
plt.ylabel('count')
plt.show()

# %%
df_tmp.head()
# Out:
#                     name  copiesSold  price   revenue  avgPlaytime  \
# 0         Shipwrecked 64       26225   7.99  202048.0     7.407743
# 1  Mothers and Daughters        7578   9.99   64494.0     4.364727
# 2   Alex Jones: NWO Wars       20806  17.76  323316.0     1.366906
# 3              Akai Onna       12475   2.99   28485.0     0.692439
# 4      TRAMCITY HAKODATE        1888  14.99   25471.0     2.946588
#
#    reviewScore publisherClass     publishers                      developers  \
# 0           96          Indie  Cogware Games  Squeaks D'Corgeh,Cogware Games
# 1           67          Indie        Spin256                         Spin256
# 2           94          Indie  NWO Wars Team                   NWO Wars Team
# 3           89          Indie         Yamoto                          Yamoto
# 4          100          Indie      TRAMWORKS                       TRAMWORKS
#
#    days_since_max_release is_new
# 0                     249    Old
# 1                     248    Old
# 2                     247    Old
# 3                     246    Old
# 4                     246    Old

# %%
# Buat subplots 2 baris, 3 kolom
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Plot pertama - Distribusi avgPlaytime
sns.histplot(data=df_tmp, x='avgPlaytime', kde=True, bins=50, ax=axes[0, 0])
axes[0, 0].set_title('Distribution dari avgPlaytime')

# Plot kedua - Distribusi reviewScore
sns.histplot(data=df_tmp, x='reviewScore', kde=True, bins=50, ax=axes[0, 1])
axes[0, 1].set_title('Distribution dari reviewScore')

# Plot ketiga - Distribusi revenue
sns.histplot(data=df_tmp, x='revenue', kde=True, bins=50, ax=axes[0, 2])
axes[0, 2].set_title('Distribution dari revenue')

# Plot keempat - Distribusi price
sns.histplot(data=df_tmp, x='price', kde=True, bins=50, ax=axes[1, 0])
axes[1, 0].set_title('Distribution dari price')

# Plot kelima - Distribusi copiesSold
sns.histplot(data=df_tmp, x='copiesSold', kde=True, bins=50, ax=axes[1, 1])
axes[1, 1].set_title('Distribution dari copiesSold')

# Plot keenam - Distribusi days_since_max_release
sns.histplot(data=df_tmp, x='days_since_max_release', kde=True, bins=50, ax=axes[1, 2])
axes[1, 2].set_title('Distribution dari days_since_max_release')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Preprocessing Data

# %%
# cek data Numerik
for label, konten in df_tmp.items():
    if pd.api.types.is_numeric_dtype(konten):
        print(label)
# Out:
# copiesSold
# price
# revenue
# avgPlaytime
# reviewScore
# days_since_max_release

# %%
# cek data objek
for label, konten in df_tmp.items():
    if pd.api.types.is_object_dtype(konten):
        print(label)
# Out:
# name
# publisherClass
# publishers
# developers
# is_new

# %% [markdown]
# ### Convert data Objek menjadi Categorical

# %%
# convert data
for label, konten in df_tmp.items():
    if pd.api.types.is_object_dtype(konten):
        df_tmp[label] = konten.astype('category')

# %%
# cek tipe data sekarang
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    1497 non-null   category
#  1   copiesSold              1497 non-null   int64
#  2   price                   1497 non-null   float64
#  3   revenue                 1497 non-null   float64
#  4   avgPlaytime             1497 non-null   float64
#  5   reviewScore             1497 non-null   int64
#  6   publisherClass          1497 non-null   category
#  7   publishers              1497 non-null   category
#  8   developers              1497 non-null   category
#  9   days_since_max_release  1497 non-null   int64
#  10  is_new                  1497 non-null   category
# dtypes: category(5), float64(3), int64(3)
# memory usage: 210.6 KB

# %% [markdown]
# ### Convert data categorikal menjadi Numerik

# %%
import warnings

# Abaikan semua warning
warnings.simplefilter("ignore")

# %%
# convert data
for label, konten in df_tmp.items():
    if pd.api.types.is_categorical_dtype(konten):
        df_tmp[label] = pd.Categorical(konten).codes

# %%
# cek tipe data sekarang
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    1497 non-null   int16
#  1   copiesSold              1497 non-null   int64
#  2   price                   1497 non-null   float64
#  3   revenue                 1497 non-null   float64
#  4   avgPlaytime             1497 non-null   float64
#  5   reviewScore             1497 non-null   int64
#  6   publisherClass          1497 non-null   int8
#  7   publishers              1497 non-null   int16
#  8   developers              1497 non-null   int16
#  9   days_since_max_release  1497 non-null   int64
#  10  is_new                  1497 non-null   int8
# dtypes: float64(3), int16(3), int64(3), int8(2)
# memory usage: 82.0 KB

# %%
df_tmp.head()
# Out:
#    name  copiesSold  price   revenue  avgPlaytime  reviewScore  \
# 0  1082       26225   7.99  202048.0     7.407743           96
# 1   786        7578   9.99   64494.0     4.364727           67
# 2    43       20806  17.76  323316.0     1.366906           94
# 3    39       12475   2.99   28485.0     0.692439           89
# 4  1200        1888  14.99   25471.0     2.946588          100
#
#    publisherClass  publishers  developers  days_since_max_release  is_new
# 0               2         178        1071                     249       1
# 1               2         887        1065                     248       1
# 2               2         634         774                     247       1
# 3               2        1047        1273                     246       1
# 4               2         929        1120                     246       1

# %%
corr_matrix = df_tmp.corr()
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="RdYlGn");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (11.5, -0.5)

# %% [markdown]
# ### Cek Outlier

# %%
col = df_tmp.columns
col
# Out:
# Index(['name', 'copiesSold', 'price', 'revenue', 'avgPlaytime', 'reviewScore',
#        'publisherClass', 'publishers', 'developers', 'days_since_max_release',
#        'is_new'],
#       dtype='object')

# %%
# Daftar kolom yang akan dicek outlier
attributes = col

# Data yang sudah dipilih
data_rmv = df_tmp[attributes]

# Ubah data_rmv menjadi format panjang menggunakan pd.melt
melted_data = pd.melt(data_rmv, var_name="Attributes", value_name="Range")

# Tentukan jumlah kolom dan baris untuk subplot
num_attributes = len(attributes)
cols = 3  # Misalnya, kita ingin 3 plot per baris
rows = (num_attributes + cols - 1) // cols  # Ini menggantikan math.ceil

# Buat subplots dengan ukuran yang sesuai
fig, axes = plt.subplots(rows, cols, figsize=(16, rows * 4))  # Adjusting height for better visibility
axes = axes.flatten()  # Flatten to easily iterate over

# Plot setiap atribut dalam subplot yang berbeda
for i, attribute in enumerate(attributes):
    sns.boxplot(x="Attributes", y="Range", data=melted_data[melted_data["Attributes"] == attribute], ax=axes[i])
    axes[i].set_title(f'{attribute}')
    axes[i].set_xlabel('')  # Remove x-axis label for clarity
    axes[i].set_ylabel('Range')

# Hapus subplot yang kosong jika ada
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Atur tata letak agar tidak saling tumpang tindih
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Handle Outlier menggunakn IQR

# %%
# Fungsi untuk menghapus outliers berdasarkan IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] >= Q1 - 1.5*IQR) & (df[column] <= Q3 + 1.5*IQR)]

# %%
df_tmp.columns
# Out:
# Index(['name', 'copiesSold', 'price', 'revenue', 'avgPlaytime', 'reviewScore',
#        'publisherClass', 'publishers', 'developers', 'days_since_max_release',
#        'is_new'],
#       dtype='object')

# %%
col_to_handle = ['copiesSold', 'price', 'revenue', 'avgPlaytime', 'reviewScore',
                 'publishers', 'developers']

def handle_outliers_iqr(df, columns):
    # Loop untuk setiap kolom yang ada di dalam col_to_handle
    for column in columns:
        # Menghitung Q1 (persentil 25) dan Q3 (persentil 75)
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        
        # Menentukan batas bawah dan batas atas untuk outlier
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Filter data untuk menghapus outliers
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df

# Contoh penggunaan
df_cleaned = handle_outliers_iqr(df_tmp[col_to_handle], col_to_handle)

# %%
df_cleaned.head()
# Out:
#    copiesSold  price   revenue  avgPlaytime  reviewScore  publishers  \
# 0       26225   7.99  202048.0     7.407743           96         178
# 1        7578   9.99   64494.0     4.364727           67         887
# 2       20806  17.76  323316.0     1.366906           94         634
# 3       12475   2.99   28485.0     0.692439           89        1047
# 4        1888  14.99   25471.0     2.946588          100         929
#
#    developers
# 0        1071
# 1        1065
# 2         774
# 3        1273
# 4        1120

# %%
# Atur style seaborn agar lebih menarik
sns.set(style="whitegrid")

# Tentukan jumlah baris berdasarkan panjang kolom
n_cols = 2  # 2 kolom per baris
n_rows = (len(col_to_handle) + 1) // n_cols  # Hitung jumlah baris yang dibutuhkan

# Buat figure dan axes dengan ukuran yang disesuaikan
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(12, n_rows * 4))

# Flatten axes jika subplot lebih dari satu baris
axes = axes.flatten()

# Loop untuk membuat boxplot untuk setiap kolom
for i, column in enumerate(col_to_handle):
    sns.boxplot(x=df_cleaned[column], ax=axes[i], palette="Set3")  # Menggunakan palette warna
    axes[i].set_title(f'Boxplot of {column}', fontsize=12, color="darkblue")  # Judul dengan style

# Hapus axis yang tidak digunakan jika jumlah kolom ganjil
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout untuk mencegah overlap
plt.tight_layout()

# Tampilkan plot
plt.show()

# %%
corr_matrix = df_cleaned.corr()
fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="RdYlGn");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (7.5, -0.5)

# %% [markdown]
# ### Melakukan Scaling Data

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

mms = MinMaxScaler()
df_scaled = mms.fit_transform(df_cleaned)

# %%
columns = df_cleaned.columns
columns
# Out:
# Index(['copiesSold', 'price', 'revenue', 'avgPlaytime', 'reviewScore',
#        'publishers', 'developers'],
#       dtype='object')

# %%
data_scaled = pd.DataFrame(data=df_scaled, columns=columns)
data_scaled.head()
# Out:
#    copiesSold     price   revenue  avgPlaytime  reviewScore  publishers  \
# 0    0.353927  0.249688  0.398337     0.347525     0.924528    0.157522
# 1    0.093698  0.312188  0.096238     0.193324     0.377358    0.784956
# 2    0.278302  0.555000  0.664668     0.041414     0.886792    0.561062
# 3    0.162038  0.093438  0.017155     0.007236     0.792453    0.926549
# 4    0.014290  0.468438  0.010535     0.121462     1.000000    0.822124
#
#    developers
# 0    0.763364
# 1    0.759088
# 2    0.551675
# 3    0.907341
# 4    0.798289

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_trans = pca.fit_transform(df_scaled)
df_pca = pd.DataFrame(data=pca_trans, columns=['PCA1', 'PCA2'])
print("Explained variance ratio:", pca.explained_variance_ratio_)
df_pca.head()
# Out:
# Explained variance ratio: [0.344508   0.19654064]
#        PCA1      PCA2
# 0 -0.056190  0.291953
# 1  0.393904 -0.188616
# 2  0.043016  0.369574
# 3  0.628257 -0.240868
# 4  0.427169 -0.158923

# %% [markdown]
# ## 6. Modelling dan Evaluasi Model

# %% [markdown]
# ### K - Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

wcss = []
scores = []
for i in range(2, 11):
    km = KMeans(n_clusters=i, n_init=10, random_state=42)
    km.fit(df_pca)
    wcss.append(km.inertia_)

    labels = km.labels_
    silhouette_avg = silhouette_score(df_pca, labels)
    scores.append(silhouette_avg)
    
    # Format angka dengan dua desimal
    print(f'wcss score for n_clusters = {i} is {wcss[-1]:.2f}')
    print('='*60)
    print(f'silhouette score for n_clusters = {i} is {silhouette_avg:.2f}')
# Out:
# wcss score for n_clusters = 2 is 100.88
# ============================================================
# silhouette score for n_clusters = 2 is 0.40
# wcss score for n_clusters = 3 is 66.88
# ============================================================
# silhouette score for n_clusters = 3 is 0.43
# wcss score for n_clusters = 4 is 49.15
# ============================================================
# silhouette score for n_clusters = 4 is 0.39
# wcss score for n_clusters = 5 is 39.75
# ============================================================
# silhouette score for n_clusters = 5 is 0.38
# wcss score for n_clusters = 6 is 33.47
# ============================================================
# silhouette score for n_clusters = 6 is 0.39
# wcss score for n_clusters = 7 is 29.01
# ============================================================
# silhouette score for n_clusters = 7 is 0.36
# wcss score for n_clusters = 8 is 25.52
# ============================================================
# silhouette score for n_clusters = 8 is 0.35
# wcss score for n_clusters = 9 is 22.19
# ============================================================
# silhouette score for n_clusters = 9 is 0.36
# wcss score for n_clusters = 10 is 19.96
# ============================================================
# silhouette score for n_clusters = 10 is 0.36

# %%
# Visualisasi Elbow Method
plt.plot(range(2, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('WCSS')
plt.show()

# Visualisasi Silhouette Score
plt.plot(range(2, 11), scores)
plt.title('Silhouette Score', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('Score')
plt.show()

# %%
k = 5
kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
cluster_labels = kmeans.fit_predict(df_pca)
centroids = kmeans.cluster_centers_

# %%
# Atur style seaborn agar lebih menarik
sns.set(style="whitegrid")

# Buat figure dengan ukuran yang lebih besar
plt.figure(figsize=(10, 8))

# Plot scatter points untuk setiap cluster, dengan ukuran dan transparansi yang sesuai
plt.scatter(df_pca.iloc[:, 0], df_pca.iloc[:, 1], 
            c=cluster_labels, cmap='viridis', s=70, alpha=0.7, edgecolor='k')

# Plot cluster centroids dengan ukuran dan warna yang lebih mencolok
plt.scatter(centroids[:, 0], centroids[:, 1], 
            c='red', marker='X', label='Centroids', s=200, edgecolor='black')

# Anotasi centroids agar lebih informatif
for i, centroid in enumerate(centroids):
    plt.text(centroid[0], centroid[1], f'  C{i+1}', color='black', fontsize=12, fontweight='bold')

# Tambahkan grid, title, dan labels
plt.title('Hasil K-means Clustering', fontsize=16, color='darkblue', fontweight='bold')
plt.xlabel('Principal Component 1', fontsize=14)
plt.ylabel('Principal Component 2', fontsize=14)

# Tampilkan legend
plt.legend(loc='best', fontsize=12)

# Tampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hasil Visualisasi 3 Dimensi

# %%
pca = PCA(n_components=3)
pca_trans = pca.fit_transform(df_scaled)
df_pca = pd.DataFrame(data=pca_trans, columns=['PCA1', 'PCA2', 'PCA3'])
print("Explained variance ratio:", pca.explained_variance_ratio_)
df_pca.head()
# Out:
# Explained variance ratio: [0.344508   0.19654064 0.14549122]
#        PCA1      PCA2      PCA3
# 0 -0.056190  0.291953 -0.288159
# 1  0.393904 -0.188616  0.033721
# 2  0.043016  0.369574 -0.150809
# 3  0.628257 -0.240868 -0.328916
# 4  0.427169 -0.158923 -0.017956

# %%
import plotly.graph_objects as go
from sklearn.cluster import KMeans

# Fitting KMeans
kmeansmodel = KMeans(n_clusters=3, random_state=42).fit(df_pca)
y_kmeans = kmeansmodel.labels_

# Scatter plot untuk Cluster 1
trace1 = go.Scatter3d(
    x=df_pca.iloc[y_kmeans == 0, 0],
    y=df_pca.iloc[y_kmeans == 0, 1],
    z=df_pca.iloc[y_kmeans == 0, 2],
    mode='markers',
    marker=dict(size=8, color='red', opacity=0.8),
    name='Cluster 1'
)

# Scatter plot untuk Cluster 2
trace2 = go.Scatter3d(
    x=df_pca.iloc[y_kmeans == 1, 0],
    y=df_pca.iloc[y_kmeans == 1, 1],
    z=df_pca.iloc[y_kmeans == 1, 2],
    mode='markers',
    marker=dict(size=8, color='blue', opacity=0.8),
    name='Cluster 2'
)

# Scatter plot untuk Cluster 3
trace3 = go.Scatter3d(
    x=df_pca.iloc[y_kmeans == 2, 0],
    y=df_pca.iloc[y_kmeans == 2, 1],
    z=df_pca.iloc[y_kmeans == 2, 2],
    mode='markers',
    marker=dict(size=8, color='green', opacity=0.8),
    name='Cluster 3'
)

# Scatter plot untuk menampilkan centroid dari K-Means
centroids = go.Scatter3d(
    x=kmeansmodel.cluster_centers_[:, 0],
    y=kmeansmodel.cluster_centers_[:, 1],
    z=kmeansmodel.cluster_centers_[:, 2],
    mode='markers',
    marker=dict(size=12, color='black', symbol='diamond', opacity=1),
    name='Centroids'
)

# Membuat layout
layout = go.Layout(
    title='Hasil KMeans Clustering',
    scene=dict(
        xaxis_title='PCA1',
        yaxis_title='PCA2',
        zaxis_title='PCA3'
    ),
    showlegend=True
)

# Menggabungkan semua trace
fig = go.Figure(data=[trace1, trace2, trace3, centroids], layout=layout)

# Menampilkan plot interaktif
fig.show()

# %% [markdown]
# ### Hierarchical Clustering (Agglomerative Clustering)

# %%
from sklearn.cluster import AgglomerativeClustering

linkage_col = ['ward', 'complete', 'average', 'single']
scores_all = [[] for _ in range(len(linkage_col))]
for j in range (len(linkage_col)):
    print('Linkage: ', linkage_col[j])
    scores = []
    for i in range(2, 10):
        AC = AgglomerativeClustering(n_clusters=i, linkage = linkage_col[j]) # Menggunakan Ward Method
        AC.fit(df_pca)
        
        labels = AC.labels_
        silhouette_avg = silhouette_score(df_pca, labels)
        scores.append(silhouette_avg)
        print('silhoutte score for n_clusters = ' + str(i) + ' is ' + str(silhouette_avg))
    print("\=======================================================\n")
    scores_all[j] = scores
# Out:
# Linkage:  ward
# silhoutte score for n_clusters = 2 is 0.3402685838435005
# silhoutte score for n_clusters = 3 is 0.39234848374130027
# silhoutte score for n_clusters = 4 is 0.33487610750792707
# silhoutte score for n_clusters = 5 is 0.3377314619074969
# silhoutte score for n_clusters = 6 is 0.284561332029482
# silhoutte score for n_clusters = 7 is 0.29547300384395847
# silhoutte score for n_clusters = 8 is 0.30139657206306414
# silhoutte score for n_clusters = 9 is 0.3161270529726771
# \=======================================================
#
# Linkage:  complete
# silhoutte score for n_clusters = 2 is 0.3420425432266723
# silhoutte score for n_clusters = 3 is 0.40173605752536523
# silhoutte score for n_clusters = 4 is 0.37357654725370143
# silhoutte score for n_clusters = 5 is 0.3281827741689956
# silhoutte score for n_clusters = 6 is 0.2773429888575464
# silhoutte score for n_clusters = 7 is 0.2772409034717962
# silhoutte score for n_clusters = 8 is 0.2837818986017574
# silhoutte score for n_clusters = 9 is 0.2787217088966846
# \=======================================================
#
# Linkage:  average
# silhoutte score for n_clusters = 2 is 0.39136449177465094
# silhoutte score for n_clusters = 3 is 0.3003411701465086
# silhoutte score for n_clusters = 4 is 0.3609551535843095
# silhoutte score for n_clusters = 5 is 0.272840019323257
# silhoutte score for n_clusters = 6 is 0.2787383817381292
# silhoutte score for n_clusters = 7 is 0.2699693669437754
# silhoutte score for n_clusters = 8 is 0.2908525146587945
# silhoutte score for n_clusters = 9 is 0.2863076821382355
# \=======================================================
#
# Linkage:  single
# silhoutte score for n_clusters = 2 is 0.4459519355835067
# silhoutte score for n_clusters = 3 is 0.3000001927288614
# silhoutte score for n_clusters = 4 is 0.2987669187798758
# silhoutte score for n_clusters = 5 is 0.28271434960847697
# silhoutte score for n_clusters = 6 is 0.27385972592204605
# silhoutte score for n_clusters = 7 is 0.24637843883968885
# silhoutte score for n_clusters = 8 is 0.2278783250383671
# silhoutte score for n_clusters = 9 is 0.18473270970718136
# \=======================================================

# %%
colors = sns.color_palette("Set1", len(linkage_col))

for j in range(len(linkage_col)):
    plt.plot(range(2, 10), scores_all[j], marker='o', color=colors[j], label=linkage_col[j])

plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs. Number of Clusters for Different Linkage Methods')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Agglomerative Clustering
n_cluster = 3
AC = AgglomerativeClustering(n_clusters=n_cluster, linkage='ward')
labels = AC.fit_predict(df_pca)

# Gabungkan df_pca dengan label clustering
df_train_with_labels = np.column_stack((df_pca.values, labels))  # Gunakan .values jika df_pca adalah DataFrame

# Hitung centroids untuk setiap cluster
centroids = []
for cluster_label in range(n_cluster):
    cluster_data = df_train_with_labels[df_train_with_labels[:, -1] == cluster_label]
    cluster_centroid = np.mean(cluster_data[:, :-1], axis=0)
    centroids.append(cluster_centroid)

centroids = np.array(centroids)

# Plotting
plt.figure(figsize=(8, 6))

# Akses kolom dari df_pca dengan .iloc jika df_pca adalah DataFrame
x = df_pca.iloc[:, 0]
y = df_pca.iloc[:, 1]

# Scatter plot untuk data points dan centroids
plt.scatter(x, y, c=labels, cmap='rainbow', label='Data Points', alpha=0.7, edgecolor='k')
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', marker='*', s=200, label='Centroids')

# Pengaturan tampilan
plt.title('Agglomerative Clustering Scatter Plot with Centroids', fontsize=14, color='darkblue')
plt.xlabel('PCA 1', fontsize=12)
plt.ylabel('PCA 2', fontsize=12)
plt.colorbar(label='Cluster')
plt.legend()

# Tampilkan plot
plt.tight_layout()
plt.show()

# %%
import scipy.cluster.hierarchy as sch

linked = sch.linkage(df_pca, 'ward')

# %%
plt.figure(figsize=(15, 10))
dendrogram = sch.dendrogram(linked, orientation='top',distance_sort='descending', show_leaf_counts=True)
plt.title('Dendrogram')
plt.xlabel('Cluster')
plt.ylabel('Distance')
plt.axhline(y=10, color='black', linestyle='--') # at this point, will divide the data into 2 clusters
plt.show()

# %% [markdown]
# # Terimakasih ^^
